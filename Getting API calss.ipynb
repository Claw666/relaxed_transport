# %%
pip install requests

# %%
import requests
import json
import urllib
from urllib.request import urlopen

# %%
response = requests.get("https://data.buienradar.nl/2.0/feed/json")
print(response)
# Out:
# <Response [200]>

# %%
json_object = response.json()

# %%
json.loads("https://data.buienradar.nl/2.0/feed/json")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12112/177933703.py in <module>
# ----> 1 json.loads("https://data.buienradar.nl/2.0/feed/json")
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
json_object
# Out:
# {'$id': '1',
#  'buienradar': {'$id': '2',
#   'copyright': '(C)opyright Buienradar / RTL. Alle rechten voorbehouden',
#   'terms': 'Deze feed mag vrij worden gebruikt onder voorwaarde van bronvermelding buienradar.nl inclusief een hyperlink naar https://www.buienradar.nl. Aan de feed kunnen door gebruikers of andere personen geen rechten worden ontleend.'},
#  'actual': {'$id': '3',
#   'actualradarurl': 'https://api.buienradar.nl/image/1.0/RadarMapNL?w=500&h=512',
#   'sunrise': '2022-03-01T07:26:00',
#   'sunset': '2022-03-01T18:19:00',
#   'stationmeasurements': [{'$id': '4',
#     'stationid': 6391,
#     'stationname': 'Meetstation Arcen',
#     'lat': 51.5,
#     'lon': 6.2,
#     'regio': 'Venlo',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'ZO',
#     'temperature': 8.7,
#     'groundtemperature': 8.1,
#     'feeltemperature': 7.8,
#     'windgusts': 3.2,
#     'windspeed': 1.8,
#     'windspeedBft': 2,
#     'humidity': 50.0,
#     'precipitation': 0.0,
#     'sunpower': 168.0,
#     'rainFallLast24Hour': 0.0,
#     'rainFallLastHour': 0.0,
#     'winddirectiondegrees': 140},
#    {'$id': '5',
#     'stationid': 6275,
#     'stationname': 'Meetstation Arnhem',
#     'lat': 52.07,
#     'lon': 5.88,
#     'regio': 'Arnhem',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'ZO',
#     'airpressure': 1028.0,
#     'temperature': 9.0,
#     'groundtemperature': 9.8,
#     'feeltemperature': 7.9,
#     'visibility': 24700.0,
#     'windgusts': 3.4,
#     'windspeed': 2.1,
#     'windspeedBft': 2,
#     'humidity': 54.0,
#     'precipitation': 0.0,
#     'sunpower': 202.0,
#     'rainFallLast24Hour': 0.0,
#     'rainFallLastHour': 0.0,
#     'winddirectiondegrees': 128},
#    {'$id': '6',
#     'stationid': 6249,
#     'stationname': 'Meetstation Berkhout',
#     'lat': 52.65,
#     'lon': 4.98,
#     'regio': 'Berkhout',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'OZO',
#     'temperature': 5.7,
#     'groundtemperature': 6.6,
#     'feeltemperature': 5.7,
#     'visibility': 16100.0,
#     'windgusts': 2.1,
#     'windspeed': 1.2,
#     'windspeedBft': 1,
#     'humidity': 79.0,
#     'precipitation': 0.0,
#     'sunpower': 122.0,
#     'rainFallLast24Hour': 2.8,
#     'rainFallLastHour': 0.1,
#     'winddirectiondegrees': 106},
#    {'$id': '7',
#     'stationid': 6308,
#     'stationname': 'Meetstation Cadzand',
#     'lat': 51.38,
#     'lon': 3.38,
#     'regio': 'Cadzand',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'Z',
#     'windgusts': 3.4,
#     'windspeed': 2.3,
#     'windspeedBft': 2,
#     'winddirectiondegrees': 178},
#    {'$id': '8',
#     'stationid': 6260,
#     'stationname': 'Meetstation De Bilt',
#     'lat': 52.1,
#     'lon': 5.18,
#     'regio': 'Utrecht',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'ZZO',
#     'airpressure': 1027.6,
#     'temperature': 7.8,
#     'groundtemperature': 7.5,
#     'feeltemperature': 6.4,
#     'visibility': 24500.0,
#     'windgusts': 3.0,
#     'windspeed': 2.2,
#     'windspeedBft': 2,
#     'humidity': 60.0,
#     'precipitation': 0.0,
#     'sunpower': 71.0,
#     'rainFallLast24Hour': 0.3,
#     'rainFallLastHour': 0.0,
#     'winddirectiondegrees': 163},
#    {'$id': '9',
#     'stationid': 6235,
#     'stationname': 'Meetstation Den Helder',
#     'lat': 52.92,
#     'lon': 4.78,
#     'regio': 'Den Helder',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt en regen',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/q.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/q',
#     'winddirection': 'NO',
#     'airpressure': 1028.1,
#     'temperature': 5.3,
#     'groundtemperature': 5.8,
#     'feeltemperature': 5.3,
#     'visibility': 8050.0,
#     'windgusts': 2.0,
#     'windspeed': 1.2,
#     'windspeedBft': 1,
#     'humidity': 90.0,
#     'precipitation': 0.2,
#     'sunpower': 126.0,
#     'rainFallLast24Hour': 6.7,
#     'rainFallLastHour': 0.4,
#     'winddirectiondegrees': 53},
#    {'$id': '10',
#     'stationid': 6370,
#     'stationname': 'Meetstation Eindhoven',
#     'lat': 51.45,
#     'lon': 5.42,
#     'regio': 'Eindhoven',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'ZO',
#     'airpressure': 1027.5,
#     'temperature': 9.3,
#     'groundtemperature': 9.6,
#     'feeltemperature': 8.3,
#     'visibility': 30400.0,
#     'windgusts': 3.1,
#     'windspeed': 2.1,
#     'windspeedBft': 2,
#     'humidity': 50.0,
#     'precipitation': 0.0,
#     'sunpower': 114.0,
#     'rainFallLast24Hour': 0.0,
#     'rainFallLastHour': 0.0,
#     'winddirectiondegrees': 135},
#    {'$id': '11',
#     'stationid': 6377,
#     'stationname': 'Meetstation Ell',
#     'lat': 51.2,
#     'lon': 5.77,
#     'regio': 'Weert',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'ZO',
#     'temperature': 9.4,
#     'groundtemperature': 10.0,
#     'feeltemperature': 8.2,
#     'visibility': 34700.0,
#     'windgusts': 3.4,
#     'windspeed': 2.3,
#     'windspeedBft': 2,
#     'humidity': 54.0,
#     'precipitation': 0.0,
#     'sunpower': 206.0,
#     'rainFallLast24Hour': 0.0,
#     'rainFallLastHour': 0.0,
#     'winddirectiondegrees': 135},
#    {'$id': '12',
#     'stationid': 6321,
#     'stationname': 'Meetstation Euro platform',
#     'lat': 52.0,
#     'lon': 3.28,
#     'regio': 'Noordzee',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'O',
#     'airpressure': 1026.9,
#     'visibility': 6050.0,
#     'windgusts': 6.4,
#     'windspeed': 5.3,
#     'windspeedBft': 3,
#     'winddirectiondegrees': 89},
#    {'$id': '13',
#     'stationid': 6350,
#     'stationname': 'Meetstation Gilze Rijen',
#     'lat': 51.57,
#     'lon': 4.93,
#     'regio': 'Gilze Rijen',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'ZO',
#     'airpressure': 1027.4,
#     'temperature': 7.9,
#     'groundtemperature': 8.0,
#     'feeltemperature': 7.2,
#     'visibility': 30900.0,
#     'windgusts': 2.7,
#     'windspeed': 1.5,
#     'windspeedBft': 1,
#     'humidity': 59.0,
#     'precipitation': 0.0,
#     'sunpower': 105.0,
#     'rainFallLast24Hour': 0.0,
#     'rainFallLastHour': 0.0,
#     'winddirectiondegrees': 136},
#    {'$id': '14',
#     'stationid': 6323,
#     'stationname': 'Meetstation Goes',
#     'lat': 51.53,
#     'lon': 3.9,
#     'regio': 'Goes',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'ZO',
#     'airpressure': 1027.1,
#     'temperature': 7.6,
#     'groundtemperature': 7.8,
#     'feeltemperature': 6.8,
#     'windgusts': 2.4,
#     'windspeed': 1.6,
#     'windspeedBft': 1,
#     'humidity': 73.0,
#     'precipitation': 0.0,
#     'sunpower': 146.0,
#     'rainFallLast24Hour': 1.0,
#     'rainFallLastHour': 0.0,
#     'winddirectiondegrees': 132},
#    {'$id': '15',
#     'stationid': 6283,
#     'stationname': 'Meetstation Groenlo-Hupsel',
#     'lat': 52.07,
#     'lon': 6.65,
#     'regio': 'Oost-Overijssel',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'ZZW',
#     'temperature': 8.9,
#     'groundtemperature': 9.5,
#     'feeltemperature': 8.3,
#     'windgusts': 2.6,
#     'windspeed': 1.6,
#     'windspeedBft': 1,
#     'humidity': 46.0,
#     'precipitation': 0.0,
#     'sunpower': 176.0,
#     'rainFallLast24Hour': 0.0,
#     'rainFallLastHour': 0.0,
#     'winddirectiondegrees': 200},
#    {'$id': '16',
#     'stationid': 6280,
#     'stationname': 'Meetstation Groningen',
#     'lat': 53.13,
#     'lon': 6.58,
#     'regio': 'Groningen',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'Z',
#     'airpressure': 1028.3,
#     'temperature': 8.0,
#     'groundtemperature': 8.6,
#     'feeltemperature': 8.0,
#     'visibility': 26900.0,
#     'windgusts': 1.8,
#     'windspeed': 1.0,
#     'windspeedBft': 1,
#     'humidity': 53.0,
#     'precipitation': 0.0,
#     'sunpower': 145.0,
#     'rainFallLast24Hour': 0.0,
#     'rainFallLastHour': 0.0,
#     'winddirectiondegrees': 174},
#    {'$id': '17',
#     'stationid': 6315,
#     'stationname': 'Meetstation Hansweert',
#     'lat': 51.45,
#     'lon': 4.0,
#     'regio': 'Oost-Zeeland',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'ZO',
#     'windgusts': 2.3,
#     'windspeed': 1.8,
#     'windspeedBft': 2,
#     'winddirectiondegrees': 139},
#    {'$id': '18',
#     'stationid': 6278,
#     'stationname': 'Meetstation Heino',
#     'lat': 52.43,
#     'lon': 6.27,
#     'regio': 'Zwolle',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'OZO',
#     'temperature': 8.7,
#     'groundtemperature': 9.4,
#     'feeltemperature': 7.8,
#     'windgusts': 2.9,
#     'windspeed': 1.8,
#     'windspeedBft': 2,
#     'humidity': 55.0,
#     'precipitation': 0.0,
#     'sunpower': 135.0,
#     'rainFallLast24Hour': 0.0,
#     'rainFallLastHour': 0.0,
#     'winddirectiondegrees': 109},
#    {'$id': '19',
#     'stationid': 6356,
#     'stationname': 'Meetstation Herwijnen',
#     'lat': 51.87,
#     'lon': 5.15,
#     'regio': 'Gorinchem',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Vrijwel onbewolkt (zonnig/helder)',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/a.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/a',
#     'winddirection': 'OZO',
#     'airpressure': 1027.6,
#     'temperature': 8.2,
#     'groundtemperature': 8.5,
#     'feeltemperature': 6.5,
#     'windgusts': 3.6,
#     'windspeed': 2.7,
#     'windspeedBft': 2,
#     'humidity': 64.0,
#     'precipitation': 0.0,
#     'sunpower': 251.0,
#     'rainFallLast24Hour': 0.0,
#     'rainFallLastHour': 0.0,
#     'winddirectiondegrees': 110},
#    {'$id': '20',
#     'stationid': 6330,
#     'stationname': 'Meetstation Hoek van Holland',
#     'lat': 51.98,
#     'lon': 4.1,
#     'regio': 'Hoek van Holland',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'ZO',
#     'airpressure': 1027.4,
#     'temperature': 6.7,
#     'groundtemperature': 7.0,
#     'feeltemperature': 6.7,
#     'windgusts': 2.4,
#     'windspeed': 1.1,
#     'windspeedBft': 1,
#     'humidity': 85.0,
#     'precipitation': 0.0,
#     'sunpower': 58.0,
#     'rainFallLast24Hour': 3.7,
#     'rainFallLastHour': 0.0,
#     'winddirectiondegrees': 138},
#    {'$id': '21',
#     'stationid': 6279,
#     'stationname': 'Meetstation Hoogeveen',
#     'lat': 52.73,
#     'lon': 6.52,
#     'regio': 'Hoogeveen',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'O',
#     'airpressure': 1028.4,
#     'temperature': 8.7,
#     'groundtemperature': 9.1,
#     'feeltemperature': 8.7,
#     'visibility': 35700.0,
#     'windgusts': 2.0,
#     'windspeed': 1.1,
#     'windspeedBft': 1,
#     'humidity': 56.0,
#     'precipitation': 0.0,
#     'sunpower': 106.0,
#     'rainFallLast24Hour': 0.0,
#     'rainFallLastHour': 0.0,
#     'winddirectiondegrees': 91},
#    {'$id': '22',
#     'stationid': 6251,
#     'stationname': 'Meetstation Hoorn Terschelling',
#     'lat': 53.38,
#     'lon': 5.35,
#     'regio': 'Wadden',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt en regen',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/q.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/q',
#     'winddirection': 'ZZO',
#     'airpressure': 1028.6,
#     'temperature': 5.1,
#     'groundtemperature': 5.7,
#     'feeltemperature': 5.1,
#     'visibility': 5420.0,
#     'windgusts': 1.4,
#     'windspeed': 0.6,
#     'windspeedBft': 1,
#     'humidity': 93.0,
#     'precipitation': 0.3,
#     'sunpower': 181.0,
#     'winddirectiondegrees': 152},
#    {'$id': '23',
#     'stationid': 6258,
#     'stationname': 'Meetstation Houtribdijk',
#     'lat': 52.65,
#     'lon': 5.4,
#     'regio': 'Enkhuizen-Lelystad',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'O',
#     'windgusts': 2.8,
#     'windspeed': 2.2,
#     'windspeedBft': 2,
#     'winddirectiondegrees': 92},
#    {'$id': '24',
#     'stationid': 6285,
#     'stationname': 'Meetstation Huibertgat',
#     'lat': 53.57,
#     'lon': 6.4,
#     'regio': 'Schiermonnikoog',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'WNW',
#     'windgusts': 1.4,
#     'windspeed': 1.0,
#     'windspeedBft': 1,
#     'winddirectiondegrees': 293},
#    {'$id': '25',
#     'stationid': 6209,
#     'stationname': 'Meetstation IJmond',
#     'lat': 52.47,
#     'lon': 4.52,
#     'regio': 'IJmond',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'ZO',
#     'windgusts': 0.7,
#     'windspeed': 0.2,
#     'windspeedBft': 0,
#     'winddirectiondegrees': 133},
#    {'$id': '26',
#     'stationid': 6225,
#     'stationname': 'Meetstation IJmuiden',
#     'lat': 52.47,
#     'lon': 4.57,
#     'regio': 'IJmuiden',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'ONO',
#     'windgusts': 1.7,
#     'windspeed': 1.0,
#     'windspeedBft': 1,
#     'winddirectiondegrees': 62},
#    {'$id': '27',
#     'stationid': 6277,
#     'stationname': 'Meetstation Lauwersoog',
#     'lat': 53.42,
#     'lon': 6.2,
#     'regio': 'Noord-Groningen',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt en regen',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/q.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/q',
#     'winddirection': 'NW',
#     'temperature': 5.3,
#     'groundtemperature': 6.1,
#     'feeltemperature': 4.4,
#     'windgusts': 2.1,
#     'windspeed': 1.4,
#     'windspeedBft': 1,
#     'humidity': 84.0,
#     'precipitation': 0.1,
#     'sunpower': 151.0,
#     'rainFallLast24Hour': 1.2,
#     'rainFallLastHour': 0.1,
#     'winddirectiondegrees': 325},
#    {'$id': '28',
#     'stationid': 6320,
#     'stationname': 'Meetstation LE Goeree',
#     'lat': 51.93,
#     'lon': 3.67,
#     'regio': 'Goeree',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'ZO',
#     'airpressure': 1027.5,
#     'visibility': 12600.0,
#     'windgusts': 2.7,
#     'windspeed': 2.0,
#     'windspeedBft': 2,
#     'winddirectiondegrees': 136},
#    {'$id': '29',
#     'stationid': 6270,
#     'stationname': 'Meetstation Leeuwarden',
#     'lat': 53.22,
#     'lon': 5.77,
#     'regio': 'Leeuwarden',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'OZO',
#     'airpressure': 1028.4,
#     'temperature': 5.8,
#     'groundtemperature': 6.5,
#     'feeltemperature': 4.5,
#     'visibility': 14300.0,
#     'windgusts': 2.5,
#     'windspeed': 1.8,
#     'windspeedBft': 2,
#     'humidity': 84.0,
#     'precipitation': 0.0,
#     'sunpower': 124.0,
#     'rainFallLast24Hour': 1.2,
#     'rainFallLastHour': 0.0,
#     'winddirectiondegrees': 106},
#    {'$id': '30',
#     'stationid': 6269,
#     'stationname': 'Meetstation Lelystad',
#     'lat': 52.45,
#     'lon': 5.53,
#     'regio': 'Lelystad',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'ONO',
#     'airpressure': 1027.9,
#     'temperature': 7.2,
#     'groundtemperature': 7.6,
#     'feeltemperature': 6.2,
#     'visibility': 21700.0,
#     'windgusts': 2.4,
#     'windspeed': 1.7,
#     'windspeedBft': 2,
#     'humidity': 66.0,
#     'precipitation': 0.0,
#     'sunpower': 170.0,
#     'rainFallLast24Hour': 0.0,
#     'rainFallLastHour': 0.0,
#     'winddirectiondegrees': 65},
#    {'$id': '31',
#     'stationid': 6348,
#     'stationname': 'Meetstation Lopik-Cabauw',
#     'lat': 51.97,
#     'lon': 4.93,
#     'regio': 'West-Utrecht',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'OZO',
#     'airpressure': 1027.6,
#     'temperature': 7.8,
#     'groundtemperature': 8.2,
#     'feeltemperature': 6.8,
#     'visibility': 25200.0,
#     'windgusts': 3.0,
#     'windspeed': 1.8,
#     'windspeedBft': 2,
#     'humidity': 66.0,
#     'precipitation': 0.0,
#     'sunpower': 107.0,
#     'rainFallLast24Hour': 0.2,
#     'rainFallLastHour': 0.0,
#     'winddirectiondegrees': 117},
#    {'$id': '32',
#     'stationid': 6380,
#     'stationname': 'Meetstation Maastricht',
#     'lat': 50.92,
#     'lon': 5.78,
#     'regio': 'Maastricht',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'Z',
#     'airpressure': 1027.7,
#     'temperature': 10.3,
#     'groundtemperature': 10.4,
#     'feeltemperature': 10.3,
#     'visibility': 39400.0,
#     'windgusts': 3.5,
#     'windspeed': 2.3,
#     'windspeedBft': 2,
#     'humidity': 41.0,
#     'precipitation': 0.0,
#     'sunpower': 174.0,
#     'rainFallLast24Hour': 0.0,
#     'rainFallLastHour': 0.0,
#     'winddirectiondegrees': 189},
#    {'$id': '33',
#     'stationid': 6273,
#     'stationname': 'Meetstation Marknesse',
#     'lat': 52.7,
#     'lon': 5.88,
#     'regio': 'Noordoostpolder',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'NNW',
#     'temperature': 7.1,
#     'groundtemperature': 7.3,
#     'feeltemperature': 7.1,
#     'visibility': 36400.0,
#     'windgusts': 1.5,
#     'windspeed': 1.0,
#     'windspeedBft': 1,
#     'humidity': 66.0,
#     'precipitation': 0.0,
#     'sunpower': 100.0,
#     'rainFallLast24Hour': 0.0,
#     'rainFallLastHour': 0.0,
#     'winddirectiondegrees': 343},
#    {'$id': '34',
#     'stationid': 6286,
#     'stationname': 'Meetstation Nieuw Beerta',
#     'lat': 53.2,
#     'lon': 7.15,
#     'regio': 'Oost-Groningen',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'ZW',
#     'temperature': 8.1,
#     'groundtemperature': 8.6,
#     'feeltemperature': 7.6,
#     'windgusts': 2.1,
#     'windspeed': 1.4,
#     'windspeedBft': 1,
#     'humidity': 61.0,
#     'precipitation': 0.0,
#     'sunpower': 152.0,
#     'rainFallLast24Hour': 0.0,
#     'rainFallLastHour': 0.0,
#     'winddirectiondegrees': 225},
#    {'$id': '35',
#     'stationid': 6312,
#     'stationname': 'Meetstation Oosterschelde',
#     'lat': 51.77,
#     'lon': 3.62,
#     'regio': 'Oosterschelde',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'OZO',
#     'windgusts': 3.1,
#     'windspeed': 2.5,
#     'windspeedBft': 2,
#     'winddirectiondegrees': 114},
#    {'$id': '36',
#     'stationid': 6344,
#     'stationname': 'Meetstation Rotterdam',
#     'lat': 51.95,
#     'lon': 4.45,
#     'regio': 'Rotterdam',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'O',
#     'airpressure': 1027.4,
#     'temperature': 7.7,
#     'groundtemperature': 8.2,
#     'feeltemperature': 7.7,
#     'visibility': 19400.0,
#     'windgusts': 1.3,
#     'windspeed': 0.3,
#     'windspeedBft': 0,
#     'humidity': 75.0,
#     'precipitation': 0.0,
#     'sunpower': 87.0,
#     'rainFallLast24Hour': 1.9,
#     'rainFallLastHour': 0.0,
#     'winddirectiondegrees': 80},
#    {'$id': '37',
#     'stationid': 6343,
#     'stationname': 'Meetstation Rotterdam Geulhaven',
#     'lat': 51.88,
#     'lon': 4.32,
#     'regio': 'Rotterdam Haven',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'ZZO',
#     'windgusts': 2.3,
#     'windspeed': 1.6,
#     'windspeedBft': 1,
#     'winddirectiondegrees': 166},
#    {'$id': '38',
#     'stationid': 6316,
#     'stationname': 'Meetstation Schaar',
#     'lat': 51.65,
#     'lon': 3.7,
#     'regio': 'Schaar',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'OZO',
#     'windgusts': 2.8,
#     'windspeed': 2.2,
#     'windspeedBft': 2,
#     'winddirectiondegrees': 106},
#    {'$id': '39',
#     'stationid': 6240,
#     'stationname': 'Meetstation Schiphol',
#     'lat': 52.3,
#     'lon': 4.77,
#     'regio': 'Amsterdam',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'O',
#     'airpressure': 1027.9,
#     'temperature': 6.2,
#     'groundtemperature': 6.7,
#     'feeltemperature': 6.2,
#     'visibility': 17800.0,
#     'windgusts': 1.8,
#     'windspeed': 1.1,
#     'windspeedBft': 1,
#     'humidity': 79.0,
#     'precipitation': 0.0,
#     'sunpower': 64.0,
#     'rainFallLast24Hour': 1.3,
#     'rainFallLastHour': 0.0,
#     'winddirectiondegrees': 81},
#    {'$id': '40',
#     'stationid': 6324,
#     'stationname': 'Meetstation Stavenisse',
#     'lat': 51.6,
#     'lon': 4.0,
#     'regio': 'Midden-Zeeland',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'ZZO',
#     'windgusts': 2.3,
#     'windspeed': 1.4,
#     'windspeedBft': 1,
#     'winddirectiondegrees': 147},
#    {'$id': '41',
#     'stationid': 6267,
#     'stationname': 'Meetstation Stavoren',
#     'lat': 52.88,
#     'lon': 5.38,
#     'regio': 'West-Friesland',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'OZO',
#     'temperature': 5.3,
#     'groundtemperature': 6.2,
#     'feeltemperature': 4.4,
#     'visibility': 15000.0,
#     'windgusts': 2.4,
#     'windspeed': 1.4,
#     'windspeedBft': 1,
#     'humidity': 82.0,
#     'precipitation': 0.0,
#     'sunpower': 188.0,
#     'rainFallLast24Hour': 1.7,
#     'rainFallLastHour': 0.0,
#     'winddirectiondegrees': 114},
#    {'$id': '42',
#     'stationid': 6229,
#     'stationname': 'Meetstation Texelhors',
#     'lat': 53.0,
#     'lon': 4.75,
#     'regio': 'Texel',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'ONO',
#     'windgusts': 2.2,
#     'windspeed': 1.7,
#     'windspeedBft': 2,
#     'winddirectiondegrees': 58},
#    {'$id': '43',
#     'stationid': 6331,
#     'stationname': 'Meetstation Tholen',
#     'lat': 51.52,
#     'lon': 4.13,
#     'regio': 'Tholen',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c'},
#    {'$id': '44',
#     'stationid': 6290,
#     'stationname': 'Meetstation Twente',
#     'lat': 52.27,
#     'lon': 6.9,
#     'regio': 'Twente',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'ZO',
#     'airpressure': 1028.4,
#     'temperature': 9.0,
#     'groundtemperature': 9.5,
#     'feeltemperature': 8.4,
#     'visibility': 23800.0,
#     'windgusts': 2.4,
#     'windspeed': 1.6,
#     'windspeedBft': 1,
#     'humidity': 48.0,
#     'precipitation': 0.0,
#     'sunpower': 209.0,
#     'rainFallLast24Hour': 0.0,
#     'rainFallLastHour': 0.0,
#     'winddirectiondegrees': 142},
#    {'$id': '45',
#     'stationid': 6313,
#     'stationname': 'Meetstation Vlakte aan de Raan',
#     'lat': 51.5,
#     'lon': 3.25,
#     'regio': 'West-Zeeland',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'ZO',
#     'windgusts': 4.5,
#     'windspeed': 3.7,
#     'windspeedBft': 3,
#     'winddirectiondegrees': 137},
#    {'$id': '46',
#     'stationid': 6242,
#     'stationname': 'Meetstation Vlieland',
#     'lat': 53.25,
#     'lon': 4.92,
#     'regio': 'Vlieland',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'OZO',
#     'airpressure': 1028.5,
#     'temperature': 5.6,
#     'groundtemperature': 6.7,
#     'feeltemperature': 4.7,
#     'visibility': 5040.0,
#     'windgusts': 2.0,
#     'windspeed': 1.4,
#     'windspeedBft': 1,
#     'humidity': 93.0,
#     'winddirectiondegrees': 114},
#    {'$id': '47',
#     'stationid': 6310,
#     'stationname': 'Meetstation Vlissingen',
#     'lat': 51.45,
#     'lon': 3.6,
#     'regio': 'Vlissingen',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'OZO',
#     'airpressure': 1026.9,
#     'temperature': 7.0,
#     'groundtemperature': 6.4,
#     'feeltemperature': 5.0,
#     'visibility': 12800.0,
#     'windgusts': 3.6,
#     'windspeed': 2.9,
#     'windspeedBft': 2,
#     'humidity': 82.0,
#     'precipitation': 0.0,
#     'sunpower': 58.0,
#     'rainFallLast24Hour': 0.8,
#     'rainFallLastHour': 0.0,
#     'winddirectiondegrees': 104},
#    {'$id': '48',
#     'stationid': 6375,
#     'stationname': 'Meetstation Volkel',
#     'lat': 51.65,
#     'lon': 5.7,
#     'regio': 'Uden',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'ZO',
#     'airpressure': 1027.7,
#     'temperature': 8.3,
#     'groundtemperature': 8.6,
#     'feeltemperature': 6.7,
#     'visibility': 42700.0,
#     'windgusts': 4.2,
#     'windspeed': 2.6,
#     'windspeedBft': 2,
#     'humidity': 53.0,
#     'precipitation': 0.0,
#     'sunpower': 117.0,
#     'rainFallLast24Hour': 0.0,
#     'rainFallLastHour': 0.0,
#     'winddirectiondegrees': 142},
#    {'$id': '49',
#     'stationid': 6215,
#     'stationname': 'Meetstation Voorschoten',
#     'lat': 52.12,
#     'lon': 4.43,
#     'regio': 'Voorschoten',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'O',
#     'airpressure': 1027.6,
#     'temperature': 6.4,
#     'groundtemperature': 6.9,
#     'feeltemperature': 5.7,
#     'visibility': 13100.0,
#     'windgusts': 2.1,
#     'windspeed': 1.4,
#     'windspeedBft': 1,
#     'humidity': 84.0,
#     'precipitation': 0.0,
#     'sunpower': 66.0,
#     'rainFallLast24Hour': 1.2,
#     'rainFallLastHour': 0.0,
#     'winddirectiondegrees': 85},
#    {'$id': '50',
#     'stationid': 6319,
#     'stationname': 'Meetstation Westdorpe',
#     'lat': 51.23,
#     'lon': 3.83,
#     'regio': 'Terneuzen',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'ZZO',
#     'airpressure': 1027.1,
#     'temperature': 8.4,
#     'groundtemperature': 8.2,
#     'feeltemperature': 7.9,
#     'visibility': 33500.0,
#     'windgusts': 2.4,
#     'windspeed': 1.4,
#     'windspeedBft': 1,
#     'humidity': 67.0,
#     'precipitation': 0.0,
#     'sunpower': 85.0,
#     'rainFallLast24Hour': 0.4,
#     'rainFallLastHour': 0.0,
#     'winddirectiondegrees': 150},
#    {'$id': '51',
#     'stationid': 6248,
#     'stationname': 'Meetstation Wijdenes',
#     'lat': 52.63,
#     'lon': 5.17,
#     'regio': 'Hoorn',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'O',
#     'windgusts': 1.8,
#     'windspeed': 1.4,
#     'windspeedBft': 1,
#     'winddirectiondegrees': 87},
#    {'$id': '52',
#     'stationid': 6257,
#     'stationname': 'Meetstation Wijk aan Zee',
#     'lat': 52.5,
#     'lon': 4.6,
#     'regio': 'Wijk aan Zee',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'temperature': 5.7,
#     'groundtemperature': 5.9,
#     'humidity': 86.0,
#     'precipitation': 0.0,
#     'sunpower': 81.0,
#     'rainFallLast24Hour': 2.9,
#     'rainFallLastHour': 0.0},
#    {'$id': '53',
#     'stationid': 6340,
#     'stationname': 'Meetstation Woensdrecht',
#     'lat': 51.45,
#     'lon': 4.33,
#     'regio': 'Woensdrecht',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'O',
#     'airpressure': 1027.2,
#     'temperature': 8.7,
#     'groundtemperature': 8.9,
#     'feeltemperature': 7.9,
#     'visibility': 21200.0,
#     'windgusts': 3.2,
#     'windspeed': 1.7,
#     'windspeedBft': 2,
#     'humidity': 61.0,
#     'precipitation': 0.0,
#     'rainFallLast24Hour': 0.5,
#     'rainFallLastHour': 0.0,
#     'winddirectiondegrees': 91},
#    {'$id': '54',
#     'stationid': 6239,
#     'stationname': 'Meetstation Zeeplatform F-3',
#     'lat': 54.85,
#     'lon': 4.73,
#     'regio': 'Noordzee',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'NO',
#     'airpressure': 1029.3,
#     'temperature': 6.4,
#     'feeltemperature': 2.6,
#     'visibility': 33300.0,
#     'windgusts': 7.4,
#     'windspeed': 6.2,
#     'windspeedBft': 4,
#     'humidity': 91.0,
#     'winddirectiondegrees': 44},
#    {'$id': '55',
#     'stationid': 6252,
#     'stationname': 'Meetstation Zeeplatform K13',
#     'lat': 53.22,
#     'lon': 3.22,
#     'regio': 'Noordzee',
#     'timestamp': '2022-03-01T14:50:00',
#     'weatherdescription': 'Zwaar bewolkt',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/c.png',
#     'graphUrl': 'https://www.buienradar.nl/nederland/weerbericht/weergrafieken/c',
#     'winddirection': 'NO',
#     'windgusts': 7.6,
#     'windspeed': 5.9,
#     'windspeedBft': 4,
#     'winddirectiondegrees': 51}]},
#  'forecast': {'$id': '56',
#   'weatherreport': {'$id': '57',
#    'published': '2022-03-01T13:30:00',
#    'title': 'Geleidelijk droger',
#    'summary': 'Met uitzondering van het oosten en zuidoosten valt er vanmiddag soms nog wat regen maar het wordt geleidelijk aan steeds droger. De rest van de week en in het weekend blijft het droog met flink wat zon. De nachten verlopen wel koud.',
#    'text': 'Met uitzondering van het oosten en zuidoosten valt er vanmiddag soms nog wat regen maar het wordt geleidelijk aan steeds droger. De rest van de week en in het weekend blijft het droog met flink wat zon. De nachten verlopen wel koud.Vanmiddag&nbsp;overheerst de bewolking en regent het van tijd tot tijd in het noorden en de westelijke helft van het land. Later wordt het droger. In het oosten en zuidoosten blijft het droog en schijnt de zon soms. In het westen is het in de regen een graad of 5 a 6 maximaal. In het oosten en zuidoosten kan het nog een graad of 9 worden.&nbsp; In Zuid-Limburg wordt de 10 gehaald. Er waait een zwakke tot matige zuid- tot zuidoostenwind.Vanavond&nbsp;overheerst de bewolking en wordt het overal droog. Vannacht&nbsp;begint het in het oosten op te klaren en kan het een graadje gaan vriezen. In het westen wordt het niet kouder dan 4 graden. De wind waait zwak en gaat uit het oosten waaien.Morgen&nbsp;wordt het vanuit het oosten steeds zonniger. In het zuidwesten blijft de bewolking het langst aanwezig. In de middag komt de temperatuur uit op een graad of 10. Er waait een zwakke tot matige oost tot noordoostenwind.De rest van de week en in het weekend schijnt de zon volop. Pas op zondag kan er iets meer bewolking binnendrijven. Het is tamelijk zacht met 10 of 11 graden op donderdag en vrijdag. In het weekend is het met 8 graden iets frisser. In het noorden is het nog enkele graden kouder. In de nacht vriest het licht.&nbsp;',
#    'author': 'Marjon de Hond ',
#    'authorbio': 'Sinds 2019 meteoroloog en presentator bij Buienradar. Voorheen gewerkt bij de NOS en Omroep Flevoland als weervrouw. '},
#   'shortterm': {'$id': '58',
#    'startdate': '2022-03-02T00:00:00',
#    'enddate': '2022-03-06T00:00:00',
#    'forecast': 'Eerst zonnig, droog en vrij zacht. Vanaf het weekeinde kouder en een kleine kans op regen.\n\nDe kans op uitgifte van waarschuwingen is voorlopig klein.'},
#   'longterm': {'$id': '59',
#    'startdate': '2022-03-07T00:00:00',
#    'enddate': '2022-03-11T00:00:00',
#    'forecast': 'Toenemende kans op een wisselvalliger en zachter weertype. De kans op neerslag neemt geleidelijk toe naar 40-50% en de kans op maxima boven normaal naar 70%.'},
#   'fivedayforecast': [{'$id': '60',
#     'day': '2022-03-02T00:00:00',
#     'mintemperature': '2',
#     'maxtemperature': '10',
#     'mintemperatureMax': 2,
#     'mintemperatureMin': 2,
#     'maxtemperatureMax': 10,
#     'maxtemperatureMin': 10,
#     'rainChance': 10,
#     'sunChance': 50,
#     'windDirection': 'o',
#     'wind': 3,
#     'mmRainMin': 0.0,
#     'mmRainMax': 0.0,
#     'weatherdescription': 'Mix van opklaringen en middelbare of lage bewolking',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/b.png'},
#    {'$id': '61',
#     'day': '2022-03-03T00:00:00',
#     'mintemperature': '-1/0',
#     'maxtemperature': '10/11',
#     'mintemperatureMax': 0,
#     'mintemperatureMin': -1,
#     'maxtemperatureMax': 11,
#     'maxtemperatureMin': 10,
#     'rainChance': 10,
#     'sunChance': 70,
#     'windDirection': 'o',
#     'wind': 3,
#     'mmRainMin': 0.0,
#     'mmRainMax': 0.0,
#     'weatherdescription': 'Mix van opklaringen en middelbare of lage bewolking',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/b.png'},
#    {'$id': '62',
#     'day': '2022-03-04T00:00:00',
#     'mintemperature': '-2/0',
#     'maxtemperature': '8/10',
#     'mintemperatureMax': 0,
#     'mintemperatureMin': -2,
#     'maxtemperatureMax': 10,
#     'maxtemperatureMin': 8,
#     'rainChance': 10,
#     'sunChance': 60,
#     'windDirection': 'zo',
#     'wind': 3,
#     'mmRainMin': 0.0,
#     'mmRainMax': 0.0,
#     'weatherdescription': 'Mix van opklaringen en middelbare of lage bewolking',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/b.png'},
#    {'$id': '63',
#     'day': '2022-03-05T00:00:00',
#     'mintemperature': '-3/0',
#     'maxtemperature': '6/8',
#     'mintemperatureMax': 0,
#     'mintemperatureMin': -3,
#     'maxtemperatureMax': 8,
#     'maxtemperatureMin': 6,
#     'rainChance': 10,
#     'sunChance': 40,
#     'windDirection': 'o',
#     'wind': 3,
#     'mmRainMin': 0.0,
#     'mmRainMax': 0.0,
#     'weatherdescription': 'Mix van opklaringen en middelbare of lage bewolking',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/b.png'},
#    {'$id': '64',
#     'day': '2022-03-06T00:00:00',
#     'mintemperature': '-3/0',
#     'maxtemperature': '6/8',
#     'mintemperatureMax': 0,
#     'mintemperatureMin': -3,
#     'maxtemperatureMax': 8,
#     'maxtemperatureMin': 6,
#     'rainChance': 30,
#     'sunChance': 30,
#     'windDirection': 'no',
#     'wind': 3,
#     'mmRainMin': 0.0,
#     'mmRainMax': 1.0,
#     'weatherdescription': 'Mix van opklaringen en middelbare of lage bewolking',
#     'iconurl': 'https://www.buienradar.nl/resources/images/icons/weather/30x30/b.png'}]}}

# %%
json_object.get('$id')
#json_object['$id']

# %%
json_object['actual']

# %%
json_object['actual']['stationmeasurements']

# %%
data_deBilt = json_object['actual']['stationmeasurements'][18]

# %%
data_deBilt['sunpower']

# %%
data_Schipbhol = json_object['actual']['stationmeasurements'][35]

# %%
########### Python 3.2 #############
import http.client, urllib.request, urllib.parse, urllib.error, base64

headers = {
    # Request headers
    'Ocp-Apim-Subscription-Key': '92eb68cc60a24f52bfe787f213bb7acd',
}

params = urllib.parse.urlencode({
    # Request parameters
    'fromStation': 'Amsterdam Zuid',
    'toStation': 'Amsterdam Centraal',
})

try:
    conn = http.client.HTTPSConnection('gateway.apiportal.ns.nl')
    conn.request("GET", "/public-prijsinformatie/prices?%s" % params, "{body}", headers)
    response = conn.getresponse()
    data = response.read()
    print(data)
    conn.close()
except Exception as e:
    print("[Errno {0}] {1}".format(e.errno, e.strerror))

# %%
########### Python 3.2 #############
import http.client, urllib.request, urllib.parse, urllib.error, base64

headers = {
    # Request headers
    'Ocp-Apim-Subscription-Key': '{subscription key}',
}

params = urllib.parse.urlencode({
})

try:
    conn = http.client.HTTPSConnection('gateway.apiportal.ns.nl')
    conn.request("GET", "/ovfiets/locations/{id}?%s" % params, "{body}", headers)
    response = conn.getresponse()
    data = response.read()
    print(data)
    conn.close()
except Exception as e:
    print("[Errno {0}] {1}".format(e.errno, e.strerror))

####################################

# %%
pip install transport-co2
# Out:
# Requirement already satisfied: transport-co2 in c:\users\maud\anaconda3\lib\site-packages (0.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from transport_co2 import Mode
list(Mode)
# Out:
# [<Mode.LIGHT_RAIL: (2184, 156)>,
#  <Mode.SMALL_CAR: (168, 1.5)>,
#  <Mode.LARGE_CAR: (220, 1.5)>,
#  <Mode.SCOOTER: (86.4, 1.2)>,
#  <Mode.BUS: (863, 12.7)>,
#  <Mode.WALK: (0, 1)>,
#  <Mode.CAR: (194, 1.5)>,
#  <Mode.SUBWAY: (193.44, 31)>,
#  <Mode.FERRY: (7425.6, 91)>,
#  <Mode.TRANSIT: (1080.1466666666668, 66.56666666666666)>,
#  <Mode.AIRPLANE: (25080, 88)>]

# %%
Mode.SMALL_CAR.estimate_co2(distance_in_km=100)
# Out:
# 11200.0

# %%
from transport_co2 import estimate_co2

# %%
estimate_co2(mode="light_rail", distance_in_km=100)
# Out:
# 1400.0

# %%
estimate_co2(mode="small_car", distance_in_km=100)
# Out:
# 11200.0

# %%
#https://www.sncf-connect.com/en-ch/help/calculation-co2-emissions-your-train-journey

# %%
pip install newsapi-python
# Out:
# Requirement already satisfied: newsapi-python in c:\users\maud\anaconda3\lib\site-packages (0.2.6)
# Requirement already satisfied: requests<3.0.0 in c:\users\maud\anaconda3\lib\site-packages (from newsapi-python) (2.26.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\maud\anaconda3\lib\site-packages (from requests<3.0.0->newsapi-python) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\maud\anaconda3\lib\site-packages (from requests<3.0.0->newsapi-python) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\maud\anaconda3\lib\site-packages (from requests<3.0.0->newsapi-python) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\maud\anaconda3\lib\site-packages (from requests<3.0.0->newsapi-python) (2021.10.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
from newsapi import NewsApiClient

# Init
newsapi = NewsApiClient(api_key='1a4d8245dd4243299fe7ee96b5b3c7c3')

# /v2/top-headlines
top_headlines = newsapi.get_top_headlines(q='bitcoin',
                                          sources='bbc-news,the-verge',
                                          category='business',
                                          language='en',
                                          country='us')

# /v2/everything
all_articles = newsapi.get_everything(q='bitcoin',
                                      sources='bbc-news,the-verge',
                                      domains='bbc.co.uk,techcrunch.com',
                                      from_param='2017-12-01',
                                      to='2017-12-12',
                                      language='en',
                                      sort_by='relevancy',
                                      page=2)

# /v2/top-headlines/sources
sources = newsapi.get_sources()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12112/376388972.py in <module>
#       5
#       6 # /v2/top-headlines
# ----> 7 top_headlines = newsapi.get_top_headlines(q='bitcoin',
#       8                                           sources='bbc-news,the-verge',
#       9                                           category='business',
#
# ~\anaconda3\lib\site-packages\newsapi\newsapi_client.py in get_top_headlines(self, q, qintitle, sources, language, country, category, page_size, page)
#     103         # Sources
#     104         if (sources is not None) and ((country is not None) or (category is not None)):
# --> 105             raise ValueError("cannot mix country/category param with sources param.")
#     106
#     107         # Sources
#
# ValueError: cannot mix country/category param with sources param.

# %%
# Out:
#   File "C:\Users\Maud\AppData\Local\Temp/ipykernel_12112/1201594499.py", line 1
#     GET https://newsapi.org/v2/top-headlines?sources=bbc-news&apiKey=1a4d8245dd4243299fe7ee96b5b3c7c3
#         ^
# SyntaxError: invalid syntax

# %%
response = requests.get("https://newsapi.org/v2/top-headlines?sources=bbc-news&apiKey=1a4d8245dd4243299fe7ee96b5b3c7c3")

# %%
print(response)
# Out:
# <Response [200]>

# %%
newsjson_object = response.json()

# %%
print(newsjson_object)
# Out:
# {'status': 'ok', 'totalResults': 10, 'articles': [{'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': 'BBC News', 'title': 'Syria shopping centre blaze kills 11', 'description': 'The entire six-storey building went up in flames, killing security guards and staff.', 'url': 'http://www.bbc.co.uk/news/world-middle-east-60571615', 'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/CFA4/production/_123465135_syriafiregettyimages-1238847224.jpg', 'publishedAt': '2022-03-01T13:22:21.6003401Z', 'content': 'Image source, Getty Images\r\nImage caption, Most of those killed were security guards or staff\r\nAt least 11 people have been killed in a fire at a shopping centre in the Syrian capital, Damascus, the … [+756 chars]'}, {'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': 'BBC News', 'title': "Europe's Mars rover 'very unlikely' to launch in 2022", 'description': 'The UK-built Rosalind Franklin vehicle is caught up in the diplomatic crisis over Ukraine.', 'url': 'http://www.bbc.co.uk/news/science-environment-60566000', 'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/9C05/production/_108514993__ab19902.jpg', 'publishedAt': '2022-03-01T12:52:23.6100142Z', 'content': 'Jonathan AmosScience correspondent@BBCAmoson Twitter\r\nImage source, Max Alexander\r\nImage caption, The rover project was first approved in 2005\r\nIt\'s "very unlikely" the British-built Mars rover, Rosa… [+5007 chars]'}, {'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': 'BBC News', 'title': 'Snake Island: Ukraine says troops who swore at Russian warship are alive', 'description': 'The 13 troops were believed to have died defending Snake Island after cursing a Russian warship.', 'url': 'http://www.bbc.co.uk/news/world-europe-60554959', 'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/584A/production/_123420622_snakeisland.png', 'publishedAt': '2022-03-01T12:22:23.7971779Z', 'content': "Image source, Ukrainian Naval Forces\r\nImage caption, Zmiinyi (Snake) Island is located 48km (30 miles) south of Ukraine's mainland in the Black Sea\r\nUkraine's navy says the 13 soldiers believed to ha… [+2071 chars]"}, {'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': 'BBC News', 'title': 'Ukraine conflict: Dread in Kyiv as huge Russian convoy advances', 'description': "The sixth day of Russia's invasion unfolds with a gnawing sense of foreboding in Ukraine's capital.", 'url': 'http://www.bbc.co.uk/news/world-europe-60571884', 'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/16EFA/production/_123464939_gettyimages-1238834516.jpg', 'publishedAt': '2022-03-01T12:07:21.7200031Z', 'content': "Lyse DoucetChief international correspondent@bbclysedouceton Twitter\r\nImage caption, A man hugs his daughter before she boards an evacuation train at Kyiv's main station\r\nThere's a biting cold in Ukr… [+4639 chars]"}, {'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': 'BBC News', 'title': 'Ukraine: Kharkiv attack was a war crime, says President Zelensky', 'description': 'President Volodymyr Zelensky spoke out after dozens of civilians were reportedly killed in Kharkiv.', 'url': 'http://www.bbc.co.uk/news/world-europe-60567162', 'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/8FC6/production/_123460863_gettyimages-1238832242.jpg', 'publishedAt': '2022-03-01T07:07:25.4535144Z', 'content': "Image source, Getty Images\r\nImage caption, A destroyed school close to the centre of Ukraine's second-largest city Kharkiv\r\nUkraine's president has described the bombardment of Kharkiv, which killed … [+2980 chars]"}, {'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': 'BBC News', 'title': 'Ukraine conflict: Disney, Warner, Sony halt release of films in Russia', 'description': 'The moves come as major corporations cut business links with Russia after its invasion of Ukraine.', 'url': 'http://www.bbc.co.uk/news/business-60566286', 'urlToImage': 'https://ichef.bbci.co.uk/news/1024/bra ...

# %%
newsjson_object['articles']
# Out:
# [{'source': {'id': 'bbc-news', 'name': 'BBC News'},
#   'author': 'BBC News',
#   'title': 'Syria shopping centre blaze kills 11',
#   'description': 'The entire six-storey building went up in flames, killing security guards and staff.',
#   'url': 'http://www.bbc.co.uk/news/world-middle-east-60571615',
#   'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/CFA4/production/_123465135_syriafiregettyimages-1238847224.jpg',
#   'publishedAt': '2022-03-01T13:22:21.6003401Z',
#   'content': 'Image source, Getty Images\r\nImage caption, Most of those killed were security guards or staff\r\nAt least 11 people have been killed in a fire at a shopping centre in the Syrian capital, Damascus, the … [+756 chars]'},
#  {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#   'author': 'BBC News',
#   'title': "Europe's Mars rover 'very unlikely' to launch in 2022",
#   'description': 'The UK-built Rosalind Franklin vehicle is caught up in the diplomatic crisis over Ukraine.',
#   'url': 'http://www.bbc.co.uk/news/science-environment-60566000',
#   'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/9C05/production/_108514993__ab19902.jpg',
#   'publishedAt': '2022-03-01T12:52:23.6100142Z',
#   'content': 'Jonathan AmosScience correspondent@BBCAmoson Twitter\r\nImage source, Max Alexander\r\nImage caption, The rover project was first approved in 2005\r\nIt\'s "very unlikely" the British-built Mars rover, Rosa… [+5007 chars]'},
#  {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#   'author': 'BBC News',
#   'title': 'Snake Island: Ukraine says troops who swore at Russian warship are alive',
#   'description': 'The 13 troops were believed to have died defending Snake Island after cursing a Russian warship.',
#   'url': 'http://www.bbc.co.uk/news/world-europe-60554959',
#   'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/584A/production/_123420622_snakeisland.png',
#   'publishedAt': '2022-03-01T12:22:23.7971779Z',
#   'content': "Image source, Ukrainian Naval Forces\r\nImage caption, Zmiinyi (Snake) Island is located 48km (30 miles) south of Ukraine's mainland in the Black Sea\r\nUkraine's navy says the 13 soldiers believed to ha… [+2071 chars]"},
#  {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#   'author': 'BBC News',
#   'title': 'Ukraine conflict: Dread in Kyiv as huge Russian convoy advances',
#   'description': "The sixth day of Russia's invasion unfolds with a gnawing sense of foreboding in Ukraine's capital.",
#   'url': 'http://www.bbc.co.uk/news/world-europe-60571884',
#   'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/16EFA/production/_123464939_gettyimages-1238834516.jpg',
#   'publishedAt': '2022-03-01T12:07:21.7200031Z',
#   'content': "Lyse DoucetChief international correspondent@bbclysedouceton Twitter\r\nImage caption, A man hugs his daughter before she boards an evacuation train at Kyiv's main station\r\nThere's a biting cold in Ukr… [+4639 chars]"},
#  {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#   'author': 'BBC News',
#   'title': 'Ukraine: Kharkiv attack was a war crime, says President Zelensky',
#   'description': 'President Volodymyr Zelensky spoke out after dozens of civilians were reportedly killed in Kharkiv.',
#   'url': 'http://www.bbc.co.uk/news/world-europe-60567162',
#   'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/8FC6/production/_123460863_gettyimages-1238832242.jpg',
#   'publishedAt': '2022-03-01T07:07:25.4535144Z',
#   'content': "Image source, Getty Images\r\nImage caption, A destroyed school close to the centre of Ukraine's second-largest city Kharkiv\r\nUkraine's president has described the bombardment of Kharkiv, which killed … [+2980 chars]"},
#  {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#   'author': 'BBC News',
#   'title': 'Ukraine conflict: Disney, Warner, Sony halt release of films in Russia',
#   'description': 'The moves come as major corporations cut business links with Russia after its invasion of Ukraine.',
#   'url': 'http://www.bbc.co.uk/news/business-60566286',
#   'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/57EA/production/_123460522_8a976dd6-b103-476c-8234-4108b903070a-1.jpg',
#   'publishedAt': '2022-03-01T05:07:24.4878228Z',
#   'content': "Image caption, Pixar's new animated film Turning Red\r\nWarner Bros, Disney and Sony have halted the release of films in Russian cinemas, after the invasion of Ukraine.\r\nThe announcements mean the rele… [+2355 chars]"},
#  {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#   'author': 'BBC News',
#   'title': 'Ukraine: Boris Johnson calls for pressure on Russia ahead of Europe trip',
#   'description': 'Vladimir Putin will "feel the consequences" of invading Ukraine, the PM says, as he heads to Poland and Estonia.',
#   'url': 'http://www.bbc.co.uk/news/uk-60565392',
#   'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/16D91/production/_123458539_hi074238494.jpg',
#   'publishedAt': '2022-03-01T04:37:22.224638Z',
#   'content': 'Image caption, People fleeing the Russian invasion of Ukraine have been arriving at the Polish border\r\nPrime Minister Boris Johnson says the UK will "continue to bring maximum pressure to bear" on Ru… [+3791 chars]'},
#  {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#   'author': 'BBC News',
#   'title': "Supreme Court hears case that may derail Biden's climate plan",
#   'description': 'The justices heard an appeal from 19 mostly Republican-led states, led by coal state West Virginia.',
#   'url': 'http://www.bbc.co.uk/news/world-us-canada-60559410',
#   'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/1A77/production/_123457760_emissions_976getty.png',
#   'publishedAt': '2022-03-01T03:22:29.5830408Z',
#   'content': "Image source, Getty Images\r\nThe Supreme Court has heard arguments in the most significant environmental case in a decade, which could undermine President Joe Biden's climate plan. \r\nAt issue is the a… [+3835 chars]"},
#  {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#   'author': 'BBC News',
#   'title': 'Ros Atkins on... Russia’s nuclear threat',
#   'description': 'Ros Atkins looks at the history of nuclear tensions and deals between the US and Russia.',
#   'url': 'http://www.bbc.co.uk/news/world-60565970',
#   'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/15A6D/production/_123458688_p0brqhky.jpg',
#   'publishedAt': '2022-03-01T00:52:19.7073756Z',
#   'content': "'My husband stayed to fight, but I had to leave' Video, 00:02:12'My husband stayed to fight, but I had to leave'"},
#  {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#   'author': 'BBC News',
#   'title': 'Truck plunges off bridge into icy river',
#   'description': 'Watch the moment a tractor-trailer plunged 50ft into the water after crashing off a bridge.',
#   'url': 'http://www.bbc.co.uk/news/world-us-canada-60565910',
#   'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/180B5/production/_123458489_p0brq9m7.jpg',
#   'publishedAt': '2022-02-28T22:22:21.4582606Z',
#   'content': "'My husband stayed to fight, but I had to leave' Video, 00:02:12'My husband stayed to fight, but I had to leave'"}]

# %%
newsjson_object['articles'][0]
# Out:
# {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#  'author': 'BBC News',
#  'title': 'Syria shopping centre blaze kills 11',
#  'description': 'The entire six-storey building went up in flames, killing security guards and staff.',
#  'url': 'http://www.bbc.co.uk/news/world-middle-east-60571615',
#  'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/CFA4/production/_123465135_syriafiregettyimages-1238847224.jpg',
#  'publishedAt': '2022-03-01T13:22:21.6003401Z',
#  'content': 'Image source, Getty Images\r\nImage caption, Most of those killed were security guards or staff\r\nAt least 11 people have been killed in a fire at a shopping centre in the Syrian capital, Damascus, the … [+756 chars]'}

# %%
news_content=newsjson_object['articles'][0]['content']

# %%
print(news_content)
# Out:
# Image source, Getty Images
# Image caption, Most of those killed were security guards or staff
# At least 11 people have been killed in a fire at a shopping centre in the Syrian capital, Damascus, the … [+756 chars]

# %%
news_content[0:-4]
# Out:
# 'Image source, Getty Images\r\nImage caption, Most of those killed were security guards or staff\r\nAt least 11 people have been killed in a fire at a shopping centre in the Syrian capital, Damascus, the … [+756 ch'

# %%
response = requests.get("https://newsapi.org/v2/top-headlines?sources=nos-news&apiKey=1a4d8245dd4243299fe7ee96b5b3c7c3")

# %%
newsjson_object = response.json()

# %%
print(newsjson_object)
# Out:
# {'status': 'ok', 'totalResults': 0, 'articles': []}

# %%
response = requests.get("https://newsapi.org/v2/top-headlines?country=nl&apiKey=1a4d8245dd4243299fe7ee96b5b3c7c3")

# %%
newsjson_object = response.json()

# %%
print(newsjson_object)
# Out:
# {'status': 'ok', 'totalResults': 32, 'articles': [{'source': {'id': None, 'name': 'Dpgmedia.nl'}, 'author': None, 'title': 'Vervolging voor grootouders wegens de dood van hun kleinkind na een hondenbeet - Volkskrant', 'description': None, 'url': 'https://myprivacy.dpgmedia.nl/consent?siteKey=PUBX2BuuZfEPJ6vF&callbackUrl=https:%2f%2fwww.volkskrant.nl%2fprivacy-wall%2faccept%3fredirectUri%3d%252fnieuws-achtergrond%252fvervolging-voor-grootouders-wegens-de-dood-van-hun-kleinkind-na-een-hondenbeet%257ebb7e785e%252f', 'urlToImage': None, 'publishedAt': '2022-03-01T11:13:23Z', 'content': None}, {'source': {'id': None, 'name': 'Voetbalprimeur.nl'}, 'author': 'Ruben Winkels', 'title': "Vitesse onder vuur: 'Het blijft doodstil in Arnhem en dat is eigenlijk heel raar' - VoetbalPrimeur.nl", 'description': 'Vitesse moet zich uitspreken tegen de Russische invasie in Oekraïne, vindt Chris Woerts. De sportmarketeer stelt dat de Arnhemse club niet stil kan blijven.', 'url': 'https://www.voetbalprimeur.nl/nieuws/1020080/vitesse-onder-vuur-het-blijft-doodstil-in-arnhem-en-dat-is-eigenlijk-heel-raar.html', 'urlToImage': 'https://files.voetbalprimeur.nl/social/2022/03/01/social_3dcd0b8dc57a289287433e3a586a5ff3ab25efd1.jpg', 'publishedAt': '2022-03-01T11:05:00Z', 'content': 'Vitesse moet zich uitspreken tegen de Russische invasie in Oekraïne, vindt Chris Woerts. De sportmarketeer stelt dat de Arnhemse club niet stil kan blijven.\r\nVitesse heeft met Valeri Oyf een Russisch… [+1857 chars]'}, {'source': {'id': None, 'name': 'Www.nu.nl'}, 'author': 'NU.nl', 'title': 'Poetin vindt het na vredesonderhandelingen te vroeg voor gesprek met Zelensky - NU.nl', 'description': 'De Russische president Vladimir Poetin vindt het vooralsnog te vroeg om een gesprek in te plannen met zijn Oekraïense ambtgenoot Volodymyr Zelensky. Poetin is dinsdag door het Kremlin ingelicht over de maandag gehouden vredesonderhandelingen en zou het te vro…', 'url': 'https://www.nu.nl/spanningen-oekraine/6186957/poetin-vindt-het-na-vredesonderhandelingen-te-vroeg-voor-gesprek-met-zelensky.html', 'urlToImage': 'https://media.nu.nl/m/k5dxvf5a76y3_wd1280.jpg/poetin-vindt-het-na-vredesonderhandelingen-te-vroeg-voor-gesprek-met-zelensky.jpg', 'publishedAt': '2022-03-01T10:58:00Z', 'content': 'De Russische president Vladimir Poetin vindt het vooralsnog te vroeg om een gesprek in te plannen met zijn Oekraïense ambtgenoot Volodymyr Zelensky. Poetin is dinsdag door het Kremlin ingelicht over … [+1530 chars]'}, {'source': {'id': None, 'name': 'Nos.nl'}, 'author': None, 'title': 'In Lviv is het ook oorlog, maar zonder bommen - NOS', 'description': 'Een paar keer per dag gaat het luchtalarm. Martha en Melania kijken er niet meer van op. Ze zijn te druk met mensen helpen.', 'url': 'https://nos.nl/index.php/l/2419353', 'urlToImage': 'https://cdn.nos.nl/image/2022/03/01/836880/xxl.jpg', 'publishedAt': '2022-03-01T10:49:45Z', 'content': 'De winkels zijn dicht, net als de restaurants. In het historische centrum van Lviv zijn geen toeristen meer te vinden. De theaters, sportzalen en kerken doen dienst als opvangplekken. In de westelijk… [+3123 chars]'}, {'source': {'id': None, 'name': 'Rtlboulevard.nl'}, 'author': None, 'title': "Kijkers vinden Hélène Hendriks 'verademing' in HLF8 - RTL Boulevard", 'description': "Johnny de Mol (43) maakte gisteravond in zijn eigen programma 'HLF8' plaats voor Hélène Hendriks (41). De presentator zat ziek thuis en dus nam Hélène even het stokje van hem over, tot groot enthousiasme van de kijkers.", 'url': 'https://www.rtlboulevard.nl/entertainment/tv/artikel/5291637/helene-hendriks-johnny-de-mol-hlf8-sbs6', 'urlToImage': 'https://www.rtlboulevard.nl/sites/default/files/content/images/2021/06/12/ANP-415639183.jpg?itok=2bzULZ4g&width=2048&height=1152&impolicy=semi_dynamic', 'publishedAt': '2022-03-01T10:36:32Z', 'content': "Johnny de Mol (43) maakte gisteravond in zijn eigen programma 'HLF8' plaats voor Hélène Hendriks (41). De presentator zat ziek thuis en dus nam Hél ...

# %%
article = requests.get("https://myprivacy.dpgmedia.nl/consent?siteKey=PUBX2BuuZfEPJ6vF&callbackUrl=https:%2f%2fwww.volkskrant.nl%2fprivacy-wall%2faccept%3fredirectUri%3d%252fnieuws-achtergrond%252fvervolging-voor-grootouders-wegens-de-dood-van-hun-kleinkind-na-een-hondenbeet%257ebb7e785e%252f")

# %%
article
# Out:
# <Response [200]>

# %%
articlejson_object = article.html()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12112/890086928.py in <module>
# ----> 1 articlejson_object = article.html()
#
# AttributeError: 'Response' object has no attribute 'html'

# %%
link = "https://www.volkskrant.nl/nieuws-achtergrond/vervolging-voor-grootouders-wegens-de-dood-van-hun-kleinkind-na-een-hondenbeet~bb7e785e/"
url_response = urllib.request.urlopen(link)
url_contents = url_response.read()

# %%
url_contents
# Out:
# b'<!DOCTYPE html>\n<html lang="nl-NL" class="is-article-page  "> <head> <meta charset="utf-8"> <meta http-equiv="x-ua-compatible" content="ie=edge"> <meta name="viewport" content="width=device-width,initial-scale=1,viewport-fit=cover">     <title>Vervolging voor grootouders wegens de dood van hun kleinkind na een hondenbeet | De Volkskrant</title>     <meta property="article:section" content="Nieuws &amp; Achtergrond">  <meta property="article:published_time" content="2022-03-01T12:13:23+01:00">  <meta property="article:author" content="Elsbeth Stoker">      <meta name="description" content="De grootouders van wie de herdershond een baby doodbeet, moeten worden vervolgd wegens dood door schuld. Dat heeft het Amsterdamse gerechtshof bepa..."> <meta name="twitter:card" content="summary_large_image"> <meta name="twitter:title" content="Vervolging voor grootouders wegens de dood van hun kleinkind na een hondenbeet"> <meta name="twitter:description" content="De grootouders van wie de herdershond een baby doodbeet, moeten worden vervolgd wegens dood door schuld. Dat heeft het Amsterdamse gerechtshof bepa..."> <meta name="twitter:image" content="https://images0.persgroep.net/rcs/PJgDv5juOQU_nKcFOMC7z_QZM1k/diocontent/201503721/_fitwidth/763?appId=93a17a8fd81db0de025c8abd1cca1279&amp;quality=0.8"> <meta property="og:type" content="article"> <meta property="og:site_name" content="de Volkskrant"> <meta property="og:locale" content="nl_NL"> <meta property="og:title" content="Vervolging voor grootouders wegens de dood van hun kleinkind na een hondenbeet"> <meta property="og:description" content="De grootouders van wie de herdershond een baby doodbeet, moeten worden vervolgd wegens dood door schuld. Dat heeft het Amsterdamse gerechtshof bepa..."> <meta property="og:url" content="https://www.volkskrant.nl/gs-bb7e785e"> <meta property="og:image" content="https://images0.persgroep.net/rcs/PJgDv5juOQU_nKcFOMC7z_QZM1k/diocontent/201503721/_fitwidth/763?appId=93a17a8fd81db0de025c8abd1cca1279&amp;quality=0.8">  <link rel="preconnect" href="https://myprivacy.dpgmedia.net"> <link rel="preconnect" href="https://advertising-cdn.dpgmedia.cloud"> <link rel="preconnect" href="https://www.googletagmanager.com"> <link rel="dns-prefetch" href="https://myprivacy.dpgmedia.net"> <link rel="dns-prefetch" href="https://advertising-cdn.dpgmedia.cloud"> <link rel="dns-prefetch" href="https://www.googletagmanager.com"> <script> \n    if (typeof dtrum === \'object\') {\n        dtrum.enable();\n    }\n\n    window.APP = {\n        config: {\n            connection: {},\n            dfp: JSON.parse(null),\n            sessionCookieName: "VK_SESSION",\n        },\n        helpers: {\n            waitUntilTrue: function waitUntilTrue(fn, successCb, errorCb, delayBetweenIterations, maxIterations, _currIteration) {\n                if (!_currIteration) {\n                    setTimeout(function () {\n                        window.APP.helpers.waitUntilTrue(fn, successCb, errorCb, delayBetweenIterations, maxIterations, 1)\n                    }, 0);\n                    return;\n                }\n\n                if (fn()) {\n                    if (typeof successCb === \'function\') {\n                        successCb();\n                    }\n                } else if (_currIteration < maxIterations) {\n                    setTimeout(function () {\n                        window.APP.helpers.waitUntilTrue(fn, successCb, errorCb, delayBetweenIterations, maxIterations, _currIteration + 1)\n                    }, delayBetweenIterations);\n                } else {\n                    if (typeof errorCb === \'function\') {\n                        errorCb();\n                    }\n                }\n            },\n            debounce: function(func, wait) {\n                let timeout;\n\n                return function executedFunction() {\n                    const context = this,\n                        args = arguments;\n\n                    clearTimeout(timeo ...

# %%
image = requests.get("https://files.voetbalprimeur.nl/social/2022/03/01/social_3dcd0b8dc57a289287433e3a586a5ff3ab25efd1.jpg")

# %%
print(image)
# Out:
# <Response [200]>

# %%
link = "https://files.voetbalprimeur.nl/social/2022/03/01/social_3dcd0b8dc57a289287433e3a586a5ff3ab25efd1.jpg"
url_response = urllib.request.urlopen(link)
url_contents = url_response.read()

# %%
url_contents
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00`\x00`\x00\x00\xff\xfe\x00;CREATOR: gd-jpeg v1.0 (using IJG JPEG v80), quality = 80\n\xff\xdb\x00C\x00\x06\x04\x05\x06\x05\x04\x06\x06\x05\x06\x07\x07\x06\x08\n\x10\n\n\t\t\n\x14\x0e\x0f\x0c\x10\x17\x14\x18\x18\x17\x14\x16\x16\x1a\x1d%\x1f\x1a\x1b#\x1c\x16\x16 , #&\')*)\x19\x1f-0-(0%()(\xff\xdb\x00C\x01\x07\x07\x07\n\x08\n\x13\n\n\x13(\x1a\x16\x1a((((((((((((((((((((((((((((((((((((((((((((((((((\xff\xc0\x00\x11\x08\x02v\x04\xb0\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00\xf9q\xce$\'\xde\xad\xdbH8\xa8\xaf"\xd8\xf9\x1d\rE\x13m5\xd6\x9d\x98\xa5\x1bhi4{\xb9\xcdQ\xb9\x8c\x89\x06\x0f5z\x06\x0c\x98&\x9a\xb6\xdeu\xdcjO\x04\xd6\xce<\xcbB664]\x06;\xabV\x92g\x00\x81\x9a\xc2\xbe\x81#\xb8d\x8f\xb1\xc5hjw\x12XH"\x86C\x82:\x03Yj\xcd#\x96c\x92k)\xc7\x95\xf2\xb2\xf9\x93Z\x12\xc5\t\x18\xe6\xaf\xc2\x98\x03\x06\xab\xa6x\xab\x11\xee\x18\xcfJ\xbaj\xcc\x86l\xe9\x8d\x82\x01\xae\x8a\xc9\xc7\x98\xa6\xb9\x9d<\xe7\x18\xadxdee\xaf\xad\xc2M\xaah\xf3k+\xb3{R\x95\x92\xcd\x9a3\xc8\x15\x89\xa3\xddI\xb8\xb3d\x8c\xf7\xab\xafq\xba\x02\x1f\xa6*\xa4%UO\x943\xcfA]m\xdd\xdc\xe7\xda,\xedt\xb7.\x14\x9a\xe8%\x93\x10\x05\xc6F+\x9b\xf0\xf4\x9el\nH \x83\xdcWE1Q\x17QY\xc9\\\xe2n\xc6\x0e\xac\xfbT\x1c\x0cf\x8d4\x97\x03\xde\xab\xeb\xecM\xb1(s\x83Wt\x00\xb2Z\xc6\xdd\xf0\x01\xac\xa3O\x91\xbb\x17)\xf3$h]\xb0hB\xb2\xe6\xb9\xddC\x11\x11\xf2\x8a\xea\xaeQ|\xafz\xe4\xbcDY#\x0c\xbd\x8dD\xe9\xf3Y\xf6*\x9c\xf9n\x8d=\x10\xb1\x99y5\xb7\xacC\x1c\xf6\xe0:\x83\x81X\x9a\x06\x1d"q\xd4\xd7Gt\xa3\xca\xe7\xd2\xb7\x9a\xbe\xe6qm\x1c\x15\xccq\xc3s\x80\x80\x1c\xf5\xad\xbd\x15\x03\xdc\xc6\x1cdf\xb2|K\x98\xa7F^\x9d\xeb[C?\xbc\x89\x85N\x1e\x1c\x91\x94Mj\xcb\x9d\xa6i\xf8\xc7C\xb7\xbc\xd3\xd8\xaa\x00\xe0pEy=\xbcf\x06d#\x04\x1cW\xbc^/\x99\x00\xc8\xe0\x8a\xf2?\x11\xd9\x1b]U\xb0\xb8V\xe4\x1a\xcet\xef%>\xc3\x8dF\xa2\xe2U\xb2Tb|\xc0\x08>\xb4\xdb\x8d6\x00\xc4\x94\xe0\xd4\xf6\x91\xe4\x8c\xd6\xbc\xd6\xc2K\\\x8f\xbc\x05MZ\\\xf1*\x9dNY\x1c&\xa1\nB\xff\x00\xbb\x18\x14\x96(\xae\xf8~\x86\xa7\xd5\x17\xf7\xac:\x10j\x1bA\x82>\xb5\xc5M4\xf5:\xa6Ksb\xb1\x92\xc9T\xd9\xd8\x0c\x1a\xdf\x95A\x88}+\n\xe8|\xe6\x95H8J\xe8\xaas\xe6V*\xe3s\xd5\xe9~H\xd4{UHF^\xa6\xbc\x99N\x00\xea+\x85h\xce\xae\x83\xa1\xb9d\x90zV\x95\xcc\xab-\xb6T\xe1\xab\x15~f\x06\xa6\x92@\x80s\xf8WTg\xcb\x13\x17\x1b\xb3.\xf1dm\xc1\xb9\xacq\x94\x93\x8e\x085\xd2\\\xb2\xb2\x16\xef\x8a\xe7\xa4\x1f\xbe8\xf5\xaf+\x10\xb5\xb9\xd7Oc@\x17\x96\x15/\x93Vt\xe8\xbf\xd2\x17\x14\xb0(6\xab\xebZZ\x15\xb8\x92q\xc79\xad)S\xbc\xd0\xa5+#GV\xb27:Qp9QX\xfe\x1cs\x14\xc0\xd7y\xac\xdb}\x8f\xc3\xb26:\xadp\xba\x04e\xa4c\xf8\xd7k\xd2\xaafQw\x8b4$>f\xa1\xbe\xb4\xb5\x8d:K\xdb\x15e ...

# %%
img_data = requests.get("https://files.voetbalprimeur.nl/social/2022/03/01/social_3dcd0b8dc57a289287433e3a586a5ff3ab25efd1.jpg").content
with open('image_name.jpg', 'wb') as handler:
    handler.write(img_data)
